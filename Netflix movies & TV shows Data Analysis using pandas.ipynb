# %%
file_path = r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
import pandas as pd

df = pd.read_csv(file_path)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# 🔹 Basic Info (Data Overview)
print("Dataset Shape:", df.shape)
print("\nColumns:\n", df.columns)
# Out:
# Dataset Shape: (8807, 12)
#
# Columns:
#  Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# 🔹 Show Sample Data
print("\nFirst 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# 🔹 Handle Missing Values (Safe Method)
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna("Unknown")

# %%
# 🔹 Convert Date Column
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
# 🔹 Feature Engineering
df['year_added'] = df['date_added'].dt.year

# %%
# 🔹 Style for Graphs
plt.style.use('ggplot')

# %%
print("\n✅ Data Loaded & Preprocessed Successfully")
# Out:
# ✅ Data Loaded & Preprocessed Successfully

# %%
file_path = r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,5))  # Small vertical size

# Plot with single yellow color
df['type'].value_counts().plot(
    kind='bar',
    color='#F4C430',   # Thick yellow
    edgecolor='black',
    linewidth=1.5,
    width=0.6          # Thick bars
)

# Title Styling
plt.title(
    "Movies vs TV Shows Distribution",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

# Axis Labels
plt.xlabel(
    "Content Type",
    fontsize=11,
    fontweight='bold'
)
plt.ylabel(
    "Count",
    fontsize=11,
    fontweight='bold'
)

# Tick Styling
plt.xticks(rotation=0, fontsize=10, fontweight='bold')
plt.yticks(fontsize=10)

# Grid Styling
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Layout
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,4))  # reduce size (width height)

df['country'].value_counts().head(10).plot(
    kind='barh',
    color='#6A0DAD',      # stylish purple
    edgecolor='black'
)

plt.title(
    "Top 10 Countries by Content",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel(
    "Number of Titles",
    fontsize=11,
    fontweight='bold'
)

plt.ylabel(
    "Country",
    fontsize=11,
    fontweight='bold'
)

plt.xticks(fontsize=9)
plt.yticks(fontsize=9)

plt.grid(axis='x', linestyle='--', alpha=0.6)

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

sizes = df['rating'].value_counts().head(5).values
labels = df['rating'].value_counts().head(5).index

plt.figure(figsize=(5,5))  # Medium size

colors = ['#1f77b4', '#2ecc71', '#f39c12', '#e74c3c', '#9b59b6']  # New stylish colors

plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    colors=colors,
    startangle=140,
    textprops={'fontsize':10, 'fontweight':'bold'},
    wedgeprops={'edgecolor':'white', 'linewidth':2}
)

# Donut circle (medium size)
centre = plt.Circle((0,0),0.60,fc='white')
plt.gca().add_artist(centre)

plt.title(
    "Ratings Distribution",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))  # medium size

df['release_year'].value_counts().sort_index().plot(
    kind='line',
    color='#2ecc71',     
    linewidth=2.5,
    marker='o',
    markersize=5
)

plt.title(
    "Content Growth Over Years",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel(
    "Release Year",
    fontsize=11,
    fontweight='bold'
)

plt.ylabel(
    "Number of Titles",
    fontsize=11,
    fontweight='bold'
)

plt.xticks(fontsize=9)
plt.yticks(fontsize=9)

plt.grid(linestyle='--', alpha=0.6)

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))  # Increased vertical height

df['listed_in'].value_counts().head(10).plot(
    kind='bar',
    color='#f39c12',   
    edgecolor='black',
    linewidth=1
)

plt.title(
    "Top 10 Genres",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel(
    "Genres",
    fontsize=11,
    fontweight='bold'
)

plt.ylabel(
    "Number of Titles",
    fontsize=11,
    fontweight='bold'
)

plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(fontsize=9)

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))  # Medium size

colors = ['#FFB6C1', '#AEC6CF']  

df['type'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    colors=colors,
    startangle=140,
    textprops={'fontsize':11, 'fontweight':'bold'},
    wedgeprops={'edgecolor':'black', 'linewidth':1.5}
)

plt.title(
    "Content Distribution",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.ylabel("")  # remove ylabel

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

year_added = df['date_added'].dt.year.value_counts().sort_index()

plt.figure(figsize=(6,4))  # Medium size

plt.fill_between(
    year_added.index,
    year_added.values,
    color='#F7DC6F',   
    alpha=0.7
)

plt.plot(
    year_added.index,
    year_added.values,
    color='#e75480',   # Darker pink outline
    linewidth=2
)

plt.title(
    "Content Added Per Year",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel(
    "Year",
    fontsize=11,
    fontweight='bold'
)

plt.ylabel(
    "Number of Titles",
    fontsize=11,
    fontweight='bold'
)

plt.xticks(fontsize=9)
plt.yticks(fontsize=9)

plt.grid(linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

monthly = df['date_added'].dt.month.value_counts().sort_index()

plt.figure(figsize=(6,4))

colors = ['#FF6B6B','#4ECDC4','#FFD93D','#6BCB77','#4D96FF',
          '#FF8FAB','#F9C74F','#90BE6D','#43AA8B','#577590',
          '#F3722C','#9B5DE5']

plt.bar(monthly.index, monthly.values, color=colors)

plt.title("Monthly Trend", fontsize=14, fontweight='bold', fontfamily='serif')
plt.xlabel("Month", fontsize=11, fontweight='bold')
plt.ylabel("Number of Titles", fontsize=11, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

directors = df['director'].value_counts().head(10)

plt.figure(figsize=(6,5))

# Lines (thick)
plt.hlines(
    y=directors.index,
    xmin=0,
    xmax=directors.values,
    color='#FF4C4C',   
    linewidth=6
)

# Dots
plt.plot(
    directors.values,
    directors.index,
    "o",
    markersize=8,
    color='#c0392b'
)

plt.title(
    "Top Directors",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Number of Titles", fontsize=11, fontweight='bold')
plt.ylabel("Director", fontsize=11, fontweight='bold')

plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

data = df.groupby(['country','type']).size().unstack().head(10)

plt.figure(figsize=(7,5))

plt.scatter(
    data.iloc[:,0],
    data.index,
    color='#F39C12',   # Orange
    s=120,
    label=data.columns[0]
)

plt.scatter(
    data.iloc[:,1],
    data.index,
    color='#2ECC71',   # Green
    s=120,
    label=data.columns[1]
)

plt.title(
    "Country vs Type",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Number of Titles", fontsize=11, fontweight='bold')
plt.ylabel("Country", fontsize=11, fontweight='bold')

plt.legend()
plt.grid(linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

movies = df[df['type']=='Movie'].copy()
movies['duration'] = movies['duration'].str.replace(' min','', regex=False)
movies['duration'] = pd.to_numeric(movies['duration'], errors='coerce')

plt.figure(figsize=(6,4))

movies['duration'].dropna().plot(
    kind='hist',
    bins=20,
    color='#FFF3B0',     
    edgecolor='black',
    linewidth=1.2
)

plt.title(
    "Movie Duration Distribution",
    fontsize=14,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Duration (Minutes)", fontsize=11, fontweight='bold')
plt.ylabel("Number of Movies", fontsize=11, fontweight='bold')

plt.grid(linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(5,4))  

pd.crosstab(df['rating'], df['type']).plot(
    kind='bar',
    figsize=(5,4),    
    width=0.8,         
    color=['#F39C12', '#9B5DE5'], 
    edgecolor='black',
    linewidth=1.2
)

plt.title(
    "Ratings vs Type",
    fontsize=12,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Rating", fontsize=10, fontweight='bold')
plt.ylabel("Number of Titles", fontsize=10, fontweight='bold')

plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))  # Small size

df.groupby(['release_year','type']).size().unstack().plot(
    linewidth=3,                
    color=['#e74c3c', '#2c3e50'], 
    figsize=(6,4)
)

plt.title(
    "Type Over Years",
    fontsize=13,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Release Year", fontsize=10, fontweight='bold')
plt.ylabel("Number of Titles", fontsize=10, fontweight='bold')

plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.grid(linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))  

df['country'].value_counts().head(10).plot(
    kind='line',
    linewidth=3,            
    color='#F4C430',         
    marker='o',
    markersize=6
)

plt.title(
    "Country Trend",
    fontsize=13,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Country", fontsize=10, fontweight='bold')
plt.ylabel("Number of Titles", fontsize=10, fontweight='bold')

plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)

plt.grid(linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4)) 

plt.scatter(
    movies['release_year'],
    movies['duration'],
    color='#8B4513',        
    edgecolor='#F4C430',    
    alpha=0.7,
    s=50,
    linewidth=1.2
)

plt.title(
    "Release Year vs Duration",
    fontsize=13,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Release Year", fontsize=10, fontweight='bold')
plt.ylabel("Duration (Minutes)", fontsize=10, fontweight='bold')

plt.grid(linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extract year from date_added
df['year_added'] = df['date_added'].dt.year

# Set figure size
plt.figure(figsize=(5,4))

# Create heatmap
sns.heatmap(
    df[['release_year', 'year_added']].corr(),
    annot=True,
    cmap='YlOrBr',        
    linewidths=1.5,
    linecolor='black',
    fmt=".2f"
)

# Title styling
plt.title(
    "Correlation Heatmap: Release Year vs Year Added",
    fontsize=13,
    fontweight='bold',
    fontfamily='serif'
)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))

sns.boxplot(
    x='type',
    y='duration',
    hue='type',          
    data=movies,
    palette='Set2',
    linewidth=1.5,
    width=0.5,
    legend=False         
)

plt.title(
    "Movie Duration by Type",
    fontsize=13,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Type", fontsize=10, fontweight='bold')
plt.ylabel("Duration (Minutes)", fontsize=10, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter TV Shows
tv = df[df['type'] == 'TV Show']

plt.figure(figsize=(4,6))  # Vertical size

tv['duration'].value_counts().head(10).plot(
    kind='bar',
    color='#6F4E37',   
    edgecolor='black',
    linewidth=1.5,
    width=0.8         
)

plt.title(
    "TV Show Seasons",
    fontsize=13,
    fontweight='bold',
    fontfamily='serif'
)

plt.xlabel("Number of Seasons", fontsize=10, fontweight='bold')
plt.ylabel("Count", fontsize=10, fontweight='bold')

plt.xticks(rotation=45, fontsize=8)
plt.yticks(fontsize=8)

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\akank'

# %%
file_path = r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv")

# Check missing values in each column
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
missing_percent = df.isnull().sum() / len(df) * 100
missing_percent
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
df_cleaned = df.dropna()

df_cleaned.shape
# Out:
# (5332, 12)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv")

# Check missing values
print("Missing values before cleaning:")
print(df.isnull().sum())

# Fill missing values
df['director'] = df['director'].fillna('Unknown')
df['cast'] = df['cast'].fillna('Not Available')
df['country'] = df['country'].fillna('Not Specified')
df['rating'] = df['rating'].fillna(df['rating'].mode()[0])
df['date_added'] = df['date_added'].fillna('Not Available')

# Check again
print("\nMissing values after cleaning:")
print(df.isnull().sum())
# Out:
# Missing values before cleaning:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
#
# Missing values after cleaning:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv")

# Detect outliers using IQR
Q1 = df['release_year'].quantile(0.25)
Q3 = df['release_year'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# Remove outliers
df = df[(df['release_year'] >= lower) & (df['release_year'] <= upper)]

print(df.shape)
# Out:
# (8088, 12)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv")

print("Duplicates before:", df.duplicated().sum())

# Remove duplicates
df = df.drop_duplicates()

print("Duplicates after:", df.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\akank\OneDrive\Desktop\netflix_titles.csv")

# Extract numbers from duration
df['duration_numeric'] = df['duration'].str.extract('(\d+)')

# Convert to numeric
df['duration_numeric'] = pd.to_numeric(df['duration_numeric'])

# Check result
df[['duration', 'duration_numeric']].head()
# Out:
#     duration  duration_numeric
# 0     90 min              90.0
# 1  2 Seasons               2.0
# 2   1 Season               1.0
# 3   1 Season               1.0
# 4  2 Seasons               2.0
